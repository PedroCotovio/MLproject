# %% [markdown]
# # Machine Learning / Aprendizagem Automática
#
# ## Sara C. Madeira, 2019/20
#
# # ML Project  - Learning about Pet Adoption using PetFinder.my Dataset

# %% [markdown]
# ## Logistics
#
# **Students are encouraged to work in teams of 3 people**.
#
# Projects with smaller teams are allowed, in exceptional cases, but will not have better grades for this reason.
#
# The quality of the project will dictate its grade, not the number of people working.
#
# **The project's solution should be uploaded in Moodle before the end of December, 20th 2019 (last day before Christmas holidays).**
#
# Students should **upload a `.zip` file** containing all the files necessary for project evaluation.
#
# **It is mandatory to produce a Jupyter notebook containing code and text/images/tables/etc describing the solution and the results. The notebook is both the solution and the report.**
#
# **Decisions should be fundamented and results should be critically discussed.**

# %% [markdown]
# ## Tools
#
# The team should use [Python 3](https://www.python.org) and [Jupyter Notebook](http://jupyter.org), together with **[Scikit-learn](http://scikit-learn.org/stable/)**, **[Orange3](https://orange.biolab.si)**, or **both**.
#
# **[Orange3](https://orange.biolab.si)** can be used through its **[programmatic version](https://docs.orange.biolab.si/3/data-mining-library/)**, by importing and using its packages, or throught its **workflow version**.
#
# **It is up to the team to decide when to use Scikit-learn, Orange, or both.**
#
# In this context, your Jupyter notebook might have a mix of code, results, text explanations, workflow figures, etc.
#
# In case you use Orange/workflows for some tasks you should also deliver the workflow files and explain the options taken in each widget in your notebook.
#
# **You can use this noteboook and the sections below as example.**

# %% [markdown]
# ## Dataset
#
# The dataset to be analysed is **`PetFinder_dataset.csv`**, made avaliable together with this project description. This dataset, downloaded from [Kaggle](https://www.kaggle.com), contains selected data from the following competition: [PetFinder.my Adoption Prediction](https://www.kaggle.com/c/petfinder-adoption-prediction/).
#
# PetFinder.my has been Malaysia’s leading animal welfare platform since 2008, with a database of more than 150,000 animals. PetFinder collaborates closely with animal lovers, media, corporations, and global organizations to improve animal welfare. Animal adoption rates are strongly correlated to the metadata associated with their online profiles, such as descriptive text and photo characteristics. As one example, PetFinder is currently experimenting with a simple AI tool called the Cuteness Meter, which ranks how cute a pet is based on qualities present in their photos. In this competition data scientist are supposed to develop algorithms to predict the adoptability of pets - specifically, how quickly is a pet adopted? If successful, they will be adapted into AI tools that will guide shelters and rescuers around the world on improving their pet profiles' appeal, reducing animal suffering and euthanization.
#
# **In this project, your team is supposed to use only tabular data (not Images or Image Metadata) and see how far you can go in predicting and understanging PetFinder.my adoptions. You should use both supervised and unsupervised learning to tackled 2 tasks:**
#
# 1. **Task 1 (Supervised Learning) - Predicting Adoption and Adoption Speed**
# 2. **Task 2 (Unsupervised Learning) - Charactering Adopted Pets and Adoption Speed**
#
# The **`PetFinder_dataset.csv`** you should learn from has **14.993 instances** described by **24 data fields** that you might use as **categorical/numerical features** and matches the `train.csv` file made available for the competition (https://www.kaggle.com/c/petfinder-adoption-prediction/data). **The target in the original Kaggle challenge is `Adoption Speed`.**
#
# ### File Descriptions
#
# * **PetFinder_dataset.csv** - Tabular/text data for the training set
# * **breed_labels.csv** - Contains Type, and BreedName for each BreedID. Type 1 is dog, 2 is cat.
# * **color_labels.csv** - Contains ColorName for each ColorID
# * **state_labels.csv** - Contains StateName for each StateID
#
# ### Data Fields
#
# * **PetID** - Unique hash ID of pet profile (Not Used)
# * **Type** - Type of animal (1 = Dog, 2 = Cat)
# * **AdoptionSpeed - Categorical speed of adoption. Lower is faster.** This is the value to predict in the competition. See below section for more info.
# * **Name** - Name of pet (Empty if not named)
# * **Age** - Age of pet when listed, in months
# * **Breed1** - Primary breed of pet (see `BreedLabels.csv` for details)
# * **Breed2** - Secondary breed of pet, if pet is of mixed breed (Refer to BreedLabels dictionary)
# * **Gender** - Gender of pet (1 = Male, 2 = Female, 3 = Mixed, if profile represents group of pets)
# * **Color1** - Color 1 of pet (see `ColorLabel.csv` for details)
# * **Color2** - Color 2 of pet (see `ColorLabel.csv` for details)
# * **Color3** - Color 3 of pet (see `ColorLabel.csv` for details)
# * **MaturitySize** - Size at maturity (1 = Small, 2 = Medium, 3 = Large, 4 = Extra Large, 0 = Not Specified)
# * **FurLength** - Fur length (1 = Short, 2 = Medium, 3 = Long, 0 = Not Specified)
# * **Vaccinated** - Pet has been vaccinated (1 = Yes, 2 = No, 3 = Not Sure)
# * **Dewormed** - Pet has been dewormed (1 = Yes, 2 = No, 3 = Not Sure)
# * **Sterilized** - Pet has been spayed / neutered (1 = Yes, 2 = No, 3 = Not Sure)
# * **Health** - Health Condition (1 = Healthy, 2 = Minor Injury, 3 = Serious Injury, 0 = Not Specified)
# * **Quantity** - Number of pets represented in profile*
# * **Fee** - Adoption fee (0 = Free)*
# * **State** - State location in Malaysia (Refer to StateLabels dictionary)*
# * **RescuerID** - Unique hash ID of rescuer (Not Used)
# * **VideoAmt** - Total uploaded videos for this pet*
# * **PhotoAmt** - Total uploaded photos for this pet*
# * **Description** - Profile write-up for this pet. The primary language used is English, with some in Malay or Chinese.
#
# ### AdoptionSpeed
#
# The value of `AdoptionSpeed` describes how quickly, if at all, a pet is adopted:
# * 0 - Pet was adopted on the same day as it was listed.
# * 1 - Pet was adopted between 1 and 7 days (1st week) after being listed.
# * 2 - Pet was adopted between 8 and 30 days (1st month) after being listed.
# * 3 - Pet was adopted between 31 and 90 days (2nd & 3rd month) after being listed.
# * 4 - No adoption after 100 days of being listed. (There are no pets in this dataset that waited between 90 and 100 days).
#
# ### **Important Notes on Data Cleaning and Preprocessing**
#
#    1. Data can contain **errors/typos**, whose correction might improve the analysis.
#    2. Some features can contain **many values**, whose grouping in categories (aggregation into bins) might improve the analysis.
#    3. Data can contain **missing values**, that you might decide to fill. You might also decide to eliminate instances/features with high percentages of missing values.
#    4. **Not all features are necessarily important** for the analysis.
#    5. Depending on the analysis, **some features might have to be excluded**.
#    6. Class distribution is an important characteristic of the dataset that should be checked. **Class imbalance** might impair machine learning.
#
# Some potentially useful links:
#
# * Data Cleaning and Preprocessing in Scikit-learn: https://scikit-learn.org/stable/modules/preprocessing.html#
# * Data Cleaning and Preprocessing in Orange: https://docs.biolab.si//3/visual-programming/widgets/data/preprocess.html
# * Dealing with imbalance datasets: https://pypi.org/project/imbalanced-learn/ and https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets#t7

# %% [markdown]
# ## Task 0 (Know your Data) - Exploratory Data Analysis

# %% [markdown]
# ## 0.1. Loading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def load_data(fname):
    """Load CSV file with any number of consecutive features, starting in column 0, where last column is tha class"""
    df = pd.read_csv(fname)
    nc = df.shape[1] # number of columns
    matrix = df.values # Convert dataframe to darray
    table_X = matrix [:, 0:nc-1] # get featuresD
    table_X = np.delete(table_X, 21, axis=1) #remove petID
    table_X = np.delete(table_X, 18, axis=1) #remove RescuerID
    table_y = matrix [:, nc-1] # get class (last columns)           
    features = df.columns.values[0:nc-1] #get features names
    target = df.columns.values[nc-1] #get target name
    return df, table_X, table_y, features, target

# %%
# Load data

df = pd.read_csv("PetFinder_dataset.csv")

# %%
#dataset summary
df.describe()
# Out:
#                Type           Age        Breed1        Breed2        Gender  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.457614     10.452078    265.272594     74.009738      1.776162
# std        0.498217     18.155790     60.056818    123.011575      0.681592
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        1.000000      2.000000    265.000000      0.000000      1.000000
# 50%        1.000000      3.000000    266.000000      0.000000      2.000000
# 75%        2.000000     12.000000    307.000000    179.000000      2.000000
# max        2.000000    255.000000    307.000000    307.000000      3.000000
#
#              Color1        Color2        Color3  MaturitySize     FurLength  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       2.234176      3.222837      1.882012      1.862002      1.467485
# std        1.745225      2.742562      2.984086      0.547959      0.599070
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      2.000000      1.000000
# 50%        2.000000      2.000000      0.000000      2.000000      1.000000
# 75%        3.000000      6.000000      5.000000      2.000000      2.000000
# max        7.000000      7.000000      7.000000      4.000000      3.000000
#
#          Vaccinated      Dewormed    Sterilized        Health      Quantity  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.731208      1.558727      1.914227      1.036617      1.576069
# std        0.667649      0.695817      0.566172      0.199535      1.472477
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      1.000000      2.000000      1.000000      1.000000
# 50%        2.000000      1.000000      2.000000      1.000000      1.000000
# 75%        2.000000      2.000000      2.000000      1.000000      1.000000
# max        3.000000      3.000000      3.000000      3.000000     20.000000
#
#                 Fee         State      VideoAmt      PhotoAmt  AdoptionSpeed
# count  14993.000000  14993.000000  14993.000000  14993.000000   14993.000000
# mean      21.259988  41346.028347      0.056760      3.889215       2.516441
# std       78.414548     32.444153      0.346185      3.487810       1.177265
# min        0.000000  41324.000000      0.000000      0.000000       0.000000
# 25%        0.000000  41326.000000      0.000000      2.000000       2.000000
# 50%        0.000000  41326.000000      0.000000      3.000000       2.000000
# 75%        0.000000  41401.000000      0.000000      5.000000       4.000000
# max     3000.000000  41415.000000      8.000000     30.000000       4.000000

# %%
#dataset profilling
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14993 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.4% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.7 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>192.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>19 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_AdoptionSpeed"><code>AdoptionSpeed</code></a> has 410 / 2.7% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Age"><code>Age</code></a> has 179 / 1.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Breed2"><code>Breed2</code></a> has 10762 / 71.8% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Color2"><code>Color2</code></a> has 4471 / 29.8% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Color3"><code>Color3</code></a> has 10604 / 70.7% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Description"><code>Description</code></a> has a high cardinality: 14033 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Fee"><code>Fee</code></a> has 12663 / 84.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has 1257 / 8.4% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 9061 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_PhotoAmt"><code>Photo

# %% [markdown]
# Only missing values are in Name and Description
# Could be insert a global constant for each value, since the noun existence of this feature might be of importance for adoption speed.
# Must breeds are zero, which should mean that it hasen't got breed
#
# Only expected correlations (ex:color1-color2)

# %% [markdown]
# ## 0.2. Understanding Data

# %% [markdown]
# In this task you should **understand better the features**, their distribution of values, potential errors, etc and plan/describe what data preprocessing steps should be performed next. Very important also is the distribution of values in the target (class distribution).
#
# Here you can find a notebook with some examples of what you can do in **Exploratory Data Analysis**: https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook. You can also use Orange widgets for this.

# %%
#Functions
from matplotlib import pyplot as plt
import seaborn as sns
#Pie Chart

def make_pie(x):
    #get counts
    counts = []
    for i in set(x):
        counts.append(np.sum(x == i))
    #get explode
    explode = []
    for i in counts:
        if (i/sum(counts) * 100) < 5:
            explode.append(0.5)
        else:
            explode.append(0)

    #Draw pie chart
    # %matplotlib inline
    fig1, ax1 = plt.subplots()
    ax1.pie(counts, explode=explode, labels=set(x), autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax1.axis('equal')
    
    plt.show()
    
    #Compare varibles
    #From https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook
main_count = df['AdoptionSpeed'].value_counts(normalize=True).sort_index()

def prepare_plot_dict(df, col, main_count):
    main_count = dict(main_count)
    plot_dict = {}
    for i in df[col].unique():
        val_count = dict(df.loc[df[col] == i, 'AdoptionSpeed'].value_counts().sort_index())

        for k, v in main_count.items():
            if k in val_count:
                plot_dict[val_count[k]] = ((val_count[k] / sum(val_count.values())) / main_count[k]) * 100 - 100
            else:
                plot_dict[0] = 0

    return plot_dict

def make_count_plot(df, x, main_count,hue='AdoptionSpeed', title=''):

    g = sns.countplot(x=x, data=df, hue=hue);
    plt.title(f'AdoptionSpeed {title}');
    ax = g.axes

    plot_dict = prepare_plot_dict(df, x, main_count)
    
    for p in ax.patches:
        h = p.get_height() if str(p.get_height()) != 'nan' else 0
        text = f"{plot_dict[h]:.0f}%" if plot_dict[h] < 0 else f"+{plot_dict[h]:.0f}%"
        ax.annotate(text, (p.get_x() + p.get_width() / 2., h),
             ha='center', va='center', fontsize=11, color='green' if plot_dict[h] > 0 else 'red', rotation=0, xytext=(0, 10),
             textcoords='offset points')
#Bar Chart

def make_bar_chart(x):
    #From https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook

    # %matplotlib inline
    plt.figure(figsize=(14, 6));
    g = sns.countplot(x)
    ax=g.axes
    for p in ax.patches:
         ax.annotate(f"{p.get_height() * 100 / df['AdoptionSpeed'].shape[0]:.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
             ha='center', va='center', fontsize=11, color='gray', rotation=0, xytext=(0, 10),
             textcoords='offset points')
    plt.show()
    
def make_bar_stack(data, hue = "AdoptionSpeed", x = "AdoptionSpeed", y="prop"):

    props = data.groupby(data[hue])[x].value_counts(normalize=True).unstack()
    props.plot(kind='bar', stacked='False', figsize=(15, 6)).margins(0)

# %% [markdown]
# ### Target

# %%
make_pie(df['AdoptionSpeed'])

# %% [markdown]
# There is imbalance on the target but it might be usefull since the event of a pet being adopted on is first date is probably very rare, so we wish that our algoritm is under-feed with this class
# For a more scietific analisys it would be important to see diferences between features in this class vs the others to try to understand if there is something more them causalaty to it. Since our objective would be that every pet is adopted in the same day he is rescued.
# check with teacher

# %%
make_bar_chart(df['AdoptionSpeed'])

# %% [markdown]
# ### Type

# %%
make_pie(df['Type'])
#df.groupby(['Type']).agg(['count'])
# Out:
#       Name   Age Breed1 Breed2 Gender Color1 Color2 Color3 MaturitySize  \
#      count count  count  count  count  count  count  count        count
# Type
# 1     7483  8132   8132   8132   8132   8132   8132   8132         8132
# 2     6253  6861   6861   6861   6861   6861   6861   6861         6861
#
#      FurLength  ... PetID PhotoAmt AdoptionSpeed agecat breedcat namecat  \
#          count  ... count    count         count  count    count   count
# Type            ...
# 1         8132  ...  8132     8132          8132   8132     8132    8132
# 2         6861  ...  6861     6861          6861   6861     6861    6861
#
#      Adoption colorcat bicolor feecat
#         count    count   count  count
# Type
# 1        8132     8132    8132   8132
# 2        6861     6861    6861   6861
#
# [2 rows x 30 columns]

# %% [markdown]
# There isn't a great imbalence between cats and dogs in the dataset

# %%
#From https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook
main_count = df['AdoptionSpeed'].value_counts(normalize=True).sort_index()
def prepare_plot_dict(df, col, main_count):
    main_count = dict(main_count)
    plot_dict = {}
    for i in df[col].unique():
        val_count = dict(df.loc[df[col] == i, 'AdoptionSpeed'].value_counts().sort_index())

        for k, v in main_count.items():
            if k in val_count:
                plot_dict[val_count[k]] = ((val_count[k] / sum(val_count.values())) / main_count[k]) * 100 - 100
            else:
                plot_dict[0] = 0

    return plot_dict

def make_count_plot(df, x, main_count,hue='AdoptionSpeed', title=''):

    g = sns.countplot(x=x, data=df, hue=hue);
    plt.title(f'AdoptionSpeed {title}');
    ax = g.axes

    plot_dict = prepare_plot_dict(df, x, main_count)

    for p in ax.patches:
        h = p.get_height() if str(p.get_height()) != 'nan' else 0
        text = f"{plot_dict[h]:.0f}%" if plot_dict[h] < 0 else f"+{plot_dict[h]:.0f}%"
        ax.annotate(text, (p.get_x() + p.get_width() / 2., h),
             ha='center', va='center', fontsize=11, color='green' if plot_dict[h] > 0 else 'red', rotation=0, xytext=(0, 10),
             textcoords='offset points')

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='Type', main_count=main_count, title='by pet Type')

# %%
make_bar_stack(data=df, hue='Type');

# %% [markdown]
# Cat's are likely to be adopted sooner them Dogs

# %% [markdown]
# # Gender

# %%
make_bar_chart(df['Gender'])

# %% [markdown]
# Desiquilibrio no género - Existem mais fêmeas que maxos e misturado existem poucos.

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='Gender', main_count=main_count, title='by pet Gender')

# %%
make_bar_stack(data=df, hue='Gender');

# %% [markdown]
# Os machos são mais rápidamente adotados do que as fêmeas e do que género misturado

# %%
sns.countplot(x='Gender', data=df, hue='Type');

# %% [markdown]
# # Age

# %%
df['Age'].plot('hist', label='train', bins=50)

# %%
#Log
np.log1p(df['Age']).plot('hist', label='train', bins=15)

# %% [markdown]
# As idades encontram-se distribuídas num grande conjunto de valores. De seguida vão ser criadas categorias para a idade.

# %%
#Create age categories
#Enconding
#0 = 0, 1 = 1, 2 = 2, 3-5 = 3, 5-13 = 4, 13-inf = 5
#guarantee similar percentages in all categaries to balance age
import math
df['agecat'] = pd.cut(df['Age'], [0, 1, 2, 3, 5, 13,math.inf], right=False, include_lowest=True, labels=['0', '1', '2','3','4','5'])
make_bar_chart(df['agecat'])

# %% [markdown]
# A distribuição dos dados pelas categorias ficaram equilibrados

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='agecat', main_count=main_count, title='by pet Age')

# %%
make_bar_stack(data=df, hue="agecat")

# %% [markdown]
# # Dados Inválidos em 0?
#
# # -> Verificar!

# %%
make_bar_stack(data=df.loc[df['Type'] == 1], hue="agecat")
make_bar_stack(data=df.loc[df['Type'] == 2], hue="agecat")

# %% [markdown]
# # -> Talvez haja missing data nos gatos age = 0

# %% [markdown]
# A análise de dados levou a concluir que:
#
# **- Animais mais jovens são adoptados mais rápidamente**

# %%
sns.countplot(x='agecat', data=df, hue='Type')
make_bar_stack(data=df, x="agecat", hue="Type")

# %% [markdown]
# There is some imbalance in categories for types might need to be ajusted for individual type predictors
# check categories with teacher

# %%
sns.countplot(x='agecat', data=df, hue='Gender');

# %%
make_bar_stack(data=df, hue="Gender", x="agecat")

# %% [markdown]
# Although there are less mixed gender's in agecat 0 they are all have similar counts, this might happen due to people's pets get pregnant and people can't keep the litter

# %% [markdown]
# # Breed

# %%
def breeds_check(ls, off):
    not_breeds=[]
    for x in range(len(ls)):
        temp = ls[x].split()
        count = 0
        for word in temp:
            if word in ['DOG', 'CAT', 'BROWN'] or 'HAIR' in word:
                continue
            for breed in off:
                 if word in (breed):
                        count += 1
        if count == 0:
            not_breeds.append(ls[x])
    return(not_breeds)

# %%
#Load breed labels
breed_label = pd.read_csv('breed_labels.csv')
#Guarantee Uppercase
for i, breed in enumerate(breed_label['BreedName']):
    breed_label.loc[i, 'BreedName'] = breed.upper()

# %%
#Load Fci official dog breeds
fci_dog =  pd.read_csv('dog_fci.csv')
#Check non-breeds in dogs
breed_label_dogs = breed_label[breed_label.Type == 1]
not_breeds_dog = breeds_check(np.array(breed_label_dogs['BreedName']), np.array(fci_dog['name']))
not_breeds_dog
# Out:
# ['AKBASH',
#  'BEAUCERON',
#  'BOERBOEL',
#  'CAROLINA DOG',
#  'CATAHOULA LEOPARD DOG',
#  'CHINOOK',
#  'COCKAPOO',
#  'ENTLEBUCHER',
#  'FEIST',
#  'KEESHOND',
#  'LOWCHEN',
#  'MCNAB',
#  'PAPILLON',
#  'POMERANIAN',
#  'SARPLANINAC',
#  'XOLOITZCUINTLE/MEXICAN HAIRLESS',
#  'MIXED BREED']

# %% [markdown]
# We now have to deal with typos and breeds that might not be official, and aliases
# After a quick google search it checks out that all dog breeds exist with the exception of 'MIXED BREED' an alias for a mutt

# %%
#Load CFA official cat breeds
cfa_cat =  pd.read_csv('cat_cfa.csv')
cfa_cat = np.array(cfa_cat['name'])
for i, breed in enumerate(cfa_cat):
    cfa_cat[i] = breed.upper()
#Check non-breeds in cats
breed_label_cats = breed_label[breed_label.Type == 2]
not_breeds_cat = breeds_check(np.array(breed_label_cats['BreedName']), cfa_cat)
not_breeds_cat
# Out:
# ['CALICO',
#  'CANADIAN HAIRLESS',
#  'CHAUSIE',
#  'CHINCHILLA',
#  'CYMRIC',
#  'DILUTE CALICO',
#  'DILUTE TORTOISESHELL',
#  'DOMESTIC LONG HAIR',
#  'DOMESTIC MEDIUM HAIR',
#  'EXTRA-TOES CAT (HEMINGWAY POLYDACTYL)',
#  'HIMALAYAN',
#  'JAVANESE',
#  'MUNCHKIN',
#  'NEBELUNG',
#  'PIXIE-BOB',
#  'SILVER',
#  'SNOWSHOE',
#  'TABBY',
#  'TIGER',
#  'TORBIE',
#  'TORTOISESHELL',
#  'TUXEDO']

# %% [markdown]
# In cat breeds their are several non-breeds:
#
# - Descriptions:
#  * 'DOMESTIC LONG HAIR'
#  * 'DOMESTIC MEDIUM HAIR'
#  * 'EXTRA-TOES CAT (HEMINGWAY POLYDACTYL)'
# - Fur colors or patterns:
#  * 'SILVER'
#  * 'TABBY'
#  * 'TIGER'
#  * 'TORBIE'
#  * 'TORTOISESHELL'

# %%
non_breeds = [
 'DOMESTIC LONG HAIR',
 'DOMESTIC MEDIUM HAIR',
 'EXTRA-TOES CAT (HEMINGWAY POLYDACTYL)',
 'SILVER',
 'TABBY',
 'TIGER',
 'TORBIE',
 'TORTOISESHELL',
 'MIXED BREED']

# %% [markdown]
# Now let's create a new Breed Feature (breedcat):
# - Encoding:
#  * 0 - No_Breed
#  * 1 - Mixed
#  * 2 - Pure_Breed

# %%
#Set class as 2
df['breedcat'] = [2 for i in range(len(df))]
#Change if mixed
#for i in range(len(df)):
#    if df.loc[i, 'Breed1'] != df.loc[i, 'Breed2'] and df.loc[i, 'Breed2'] != 0:
#        df.loc[i, 'breedcat'] = 1
#get No_Bree's Id
non_breedf = breed_label[breed_label.BreedName.isin(non_breeds)]
non_breed = np.array(non_breedf['BreedID'])
#Change if No_Breed
for i in range(len(df)):
    if df.loc[i, 'Breed1'] in non_breed or df.loc[i, 'Breed2'] in non_breed:
        df.loc[i, 'breedcat'] = 0

# %%
make_bar_chart(df['breedcat'])

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='breedcat', main_count=main_count, title='by pet breed')

# %%
make_bar_stack(data=df, hue="breedcat")

# %% [markdown]
# Seems animals with a breed are adopted faster

# %%
sns.countplot(x='breedcat', data=df, hue='Type')

# %% [markdown]
# # Name

# %%
df['Name'].value_counts()
# Out:
# Baby                           66
# Lucky                          64
# Brownie                        54
# No Name                        54
# Mimi                           52
# Blackie                        49
# Puppy                          45
# Kitty                          39
# Max                            39
# Kittens                        39
# Oreo                           36
# Coco                           35
# Tiger                          34
# Angel                          33
# Milo                           32
# Snowy                          30
# Bobby                          30
# Kiki                           29
# Lucy                           29
# Lily                           28
# Tom                            27
# Puppies                        26
# Ginger                         26
# Prince                         25
# Happy                          25
# Daisy                          24
# Bella                          23
# Rocky                          23
# Kitten                         23
# Simba                          23
#                                ..
# Cindi                           1
# å°é»  Xiao Hei                1
# 2 Playful Kittens               1
# MARLEY & BLACKY-O               1
# LuiLui                          1
# Maryjane                        1
# Vero                            1
# Tinker Belle                    1
# Little Meow                     1
# Yucca                           1
# Rare Colour Beagle              1
# Nafa And Siblings               1
# Linsay                          1
# Kitten RR2                      1
# Roma                            1
# COMEL (booked-ajai)             1
# Donna Kitty                     1
# Gao Zai                         1
# Prada                           1
# Ah Gray                         1
# Chamelia                        1
# Achik                           1
# Shortie A.k.a Eh-Ya-Tok         1
# FOUND IN BU Up For Adoption     1
# Rambo The Cute Dog              1
# S4                              1
# Lucky Pups                      1
# Blue Eyed Dolls                 1
# Latte & Espresso                1
# Nala & Peach                    1
# Name: Name, Length: 9060, dtype: int64

# %% [markdown]
# So there are quite some names that aren't really names let's try to tell them appart

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
#list of proibided strings
prb = ['KITT', 'PUPPY', 'DOG', 'MALE', 'FEMALE','FOR', 'NO NAME', 'NAN', 'BOY', 'GIRL']
names = []
for i, name in enumerate(df['Name']):
        if is_number(name) is True or name.isdigit() is True:
            names.append(i)
        else:
            name = name.upper()
            if len(name) <3 or any(string in name for string in prb)  or any(char.isdigit() for char in name):
                names.append(i)

# %%
df.loc[names]
# Out:
#        Type                                      Name  Age  Breed1  Breed2  \
# 1         2                               No Name Yet    1     265       0
# 5         2                                       NaN    3     266       0
# 7         1                   Siu Pak & Her 6 Puppies    0     307       0
# 8         2                                       NaN    2     265       0
# 9         2                                     Kitty   12     265       0
# 13        2                   2 Mths Old Cute Kitties    2     265       0
# 14        1                                  Lost Dog    3     307       0
# 19        2                                       NaN    1     266       0
# 26        2                                   No Name    2     285     265
# 27        2                                   No Name    1     266       0
# 33        2                                       NaN    4     266       0
# 34        2                          Kitten Girl Girl    3     266       0
# 36        2                                       NaN   24     265     292
# 39        1                                       Boy   12     307       0
# 52        1                    BouncerBoy: Beagle Mix    2     307       0
# 55        2                                   Kitties    3     265       0
# 59        2                      Chocolate And Kitten    2     243       0
# 63        1                                IO-Male-03    2     307       0
# 66        2                                       NaN    3     266       0
# 71        1                                        H3    1     307     307
# 74        1                   9 Puppies For Adoption!    1     173      96
# 78        1                                        Z3    2     307     307
# 79        1                                       NaN    1     307       0
# 80        1                                 MPSP-F-01    2     307       0
# 84        2                                     Malee    6     265       0
# 85        1                               Mayo 2 Pups    1     307       0
# 87        1                          Rottweiler Puppy    2     189     307
# 88        1                      Lion Dog In Training   12     307       0
# 90        1                                  Rocky 06    1     307       0
# 92        1                                       NaN    1     307     307
# ...     ...                                       ...  ...     ...     ...
# 14856     1                                 Mimi Girl    8      75     307
# 14860     2                     5 Little Black Beauty    1     265     266
# 14869     1                                      CNY4    1     307     307
# 14871     1                                       NaN    2     307       0
# 14875     2                                 Boy@Caspi    9     264     276
# 14877     2                     Healthy Active Kitten    4     266       0
# 14878     2                               Calico Girl    3     265       0
# 14880     1                                    Boyboy   24     182       0
# 14887     1                                      Dogs    1     307     307
# 14893     2  URGENT!Female Cat With Her Three Kittens    1     265       0
# 14895     1                                        B1    2     307     307
# 14902     1                         Single Puppy Ipoh    2     307       0
# 14910     2                            Kitten N Mummy    1     266       0
# 14919     1          URGENT: Frigga The Sweetest Girl   36     307       0
# 14923     1                                 Lab Mix 3    2     307     141
# 14924     1                                     Puppy    2     307       0
# 14926     2                               Kitten RA19    2     266       0
# 14930     1                                       NaN   12     307     307
# 14934     2                                     Kitty    3     265       0
# 14935     2                                       NaN    1     243       0
# 14936     2                                    Kitten    2     292       0
# 14954     1                        5 New Born Puppies    0     307     307
# 14959     1                              D144(030217)   48      83       0
# 14968     2                           Sentul Kittiens    2     266       0
# 14970     1                   KL Puppies For Adoption    2     307       0
# 14972     2                              Kofi (annan)    2     266       0
# 14973     1                                      Zee4    2     307     307
# 14979     1                                  SambaBoy    6     307       0
# 14984     1                                       NaN   60     307       0
# 14988     2                                       NaN    2     266       0
#
#        Gender  Color1  Color2  Color3  MaturitySize  ...  Fee  State  \
# 1           1       1       2       0             2  ...    0  41401
# 5           2       5       6       0             2  ...    0  41326
# 7           2       1       2       7             2  ...    0  41326
# 8           2       6       0       0             2  ...    0  41326
# 9           2       1       7       0             2  ...    0  41326
# 13          3       1       6       7             1  ...    0  41326
# 14          2       2       5       7             2  ...    0  41401
# 19          3       1       2       7             1  ...    0  41326
# 26          1       3       0       0             2  ...    0  41401
# 27          2       1       0       0             2  ...    0  41326
# 33          2       1       6       7             1  ...    0  41326
# 34          2       1       7       0             1  ...    1  41327
# 36          2       1       4       0             2  ...    0  41326
# 39          1       5       0       0             2  ...    0  41326
# 52          1       2       7       0             2  ...    0  41326
# 55          3       4       6       7             1  ...    0  41401
# 59          3       1       6       7             1  ...    0  41401
# 63          1       1       2       0             2  ...    0  41327
# 66          2       2       0       0             2  ...    0  41324
# 71          2       1       2       0             2  ...    0  41326
# 74          3       1       2       7             2  ...  100  41335
# 78          1       2       0       0             2  ...    0  41326
# 79          2       2       7       0             2  ...    0  41326
# 80          2       1       2       0             2  ...    0  41327
# 84          2       5       7       0             2  ...   50  41326
# 85          2       1       2       0             2  ...    0  41326
# 87          1       1       2       0             3  ...    0  41326
# 88          2       5       0       0             2  ...    0  41330
# 90          1       2       0       0             2  ...    0  41330
# 92          3       2       7       0             2  ...    0  41326
# ...       ...     ...     ...     ...           ...  ...  ...    ...
# 14856       2       1       0       0             2  ...    0  41326
# 14860       3       1       0       0             2  ...   50  41326
# 14869       1       2       0       0             2  ...    0  41326
# 14871       2       4       7       0             2  ...    0  41324
# 14875       1       5       0       0             2  ...  200  41330
# 14877       1       5       7       0             2  ...    0  41401
# 14878       2       1       3       7             1  ...    0  41327
# 14880       1       5       0       0             2  ...  100  41326
# 14887       3       1       2       7             1  ...   50  41336
# 14893       3       3       5       6             2  ...    0  41336
# 14895       2       1       7       0             2  ...    0  41326
# 14902       2       2       0       0             2  ...    0  41330
# 14910       3       1       3       0             2  ...    0  41336
# 14919       2       2       7       0             3  ...    0  41326
# 14923       2       2       0       0             2  ...    0  41326
# 14924       2       1       2       7             2  ...    1  41327
# 14926       1       1       7       0             2  ...    0  41401
# 14930       1       2       7       0             2  ...    0  41401
# 14934       2       6       7       0             2  ...    0  41326
# 14935       3       2       3       4             2  ...    0  41336
# 14936       3       2       5       0             1  ...    0  41336
# 14954       3       2       7       0             1  ...    5  41326
# 14959       1       5       0       0             1  ...    0  41326
# 14968       3       3       7       0             2  ...   30  41326
# 14970       2       2       5       0             2  ...    0  41401
# 14972       1       6       0       0             2  ...    0  41401
# 14935  8d3049f2bb476520449863435ad067ec         0
# 14936  5232bdd1444960a257ccec9a41404320         0
# 14954  d6b828d594ddeb7ddbb6c0b9e75f8145         0
# 14959  d372aa7115ee3c2e5e4796462dec984b         0
# 14968  4d2400be2e2e78265f5c84345b7a3415         0
# 14970  aab827a9ea617772101d6a7610a46faa         0
# 14972  ee2747ce26468ec44c7194e7d1d9dad9         0
# 14973  b53c34474d9e24574bcec6a3d3306a0d         0
# 14979  8b6c5cd067ada5f54ca5ffc7f7b5d896         0
# 14984  c8ea0bc42e630c72747986c4c0ce36aa         0
# 14988  61c84bd7bcb6fb31d2d480b1bcf9682e         0
#
#                                              Description      PetID  PhotoAmt  \
# 1      I just found it alone yesterday near my apartm...  6296e909a       2.0
# 5      This is a stray kitten that came to my house. ...  d24c30b4b       2.0
# 7      Siu Pak just give birth on 13/6/10 to 6puppies...  97aa9eeac       9.0
# 8      healthy and active, feisty kitten found in nei...  c06d167ca       6.0
# 9      Very manja and gentle stray cat found, we woul...  7a0942d61       2.0
# 13     Hi Pet Lovers! This is my first posting and I ...  4a9793dfb       1.0
# 14     Lost Dog Found (Bandar Menjalara, Kepong／Taman...  c02be41e6       2.0
# 19     Birth Date: Oct 30th Kitty 1, Melly -Female Sa...  b10e7605a       1.0
# 26     healthy toilet trained cute easy to look after...  85fc3c314      11.0
# 27     Just saved this kitten from the street, but i ...  efbf1703a       2.0
# 33     Two gorgeous kittens have just lost their mumm...  9415bc79e       7.0
# 34                                  Open for adoption!!!  4c6fe4100       5.0
# 36                        she fat n healthy. in door cat  61fa73996       2.0
# 39     -playful -energetic dog -friendly and easily a...  4e3640544       1.0
# 52     Bouncer is a happy pup that needs a happy lovi...  015c75c9e       3.0
# 55     Rescued these 2 brother & sister kitties below...  f6551137d      15.0
# 59     The mother is about 2years and kittens are aro...  9c0ddccc8       1.0
# 63     Please help these puppies find good homes...A ...  9883a048e       5.0
# 66                 She needs a loving and caring home...  e540c1ba5       1.0
# 71                                        Dog 4 Adoption  aaf4a1439       1.0
# 74     I have two litters of puppies for adoption.. T...  45d2ddcb8       5.0
# 78                                          For Adoption  35593da00       5.0
# 79     This puppy is currently living in an abandoned...  4cc70e613       1.0
# 80     Puppy saved from MPSP pound yesterday. She is ...  ff125cf8d       1.0
# 84     Read story about Malee at She's very active,pl...  ec5069cf6       4.0
# 85     Very adorable and cute puppies Commitment to s...  867308404       3.0
# 87     We was found this dog from a roadside i think ...  258667857       4.0
# 88     Nickki is mixed breed,female, one year plus, f...  fd3172797      11.0
# 90     Puppies are five week old and looking for good...  3d0752cd9       5.0
# 92     Mother and her puppies were found in Bayu Ting...  573b3ec3d       0.0
# ...                                                  ...        ...       ...
# 14856  Medium size Dachshund mix puppy looking for a ...  1be58123d       1.0
# 14860  25/6/ Bad news: Dark Chocolate 2 & Black Coffe...  26d0bfe44       1.0
# 14869                                       For Adoption  af75249aa       3.0
# 14871     mixed breed. interested please kindly email me  5aff9022b       1.0
# 14875                                                DaH  b79275092      20.0
# 14877  rescued, lovable and active kitten looking for...  56d3aa3ac       1.0
# 14878  I found her in a drain at Bayan Lepas area..in...  13757a086       4.0
# 14880  Male. 2 years old. Cheerful. Playful. Friendly...  6e3631a29       2.0
# 14887                                       love to play  bca099371       3.0
# 14893  Lookings for a serious adopter who are willing...  b7c4936a9       4.0
# 14895                                       For Adoption  02c40b53c       5.0
# 14902  Hi my cousin.found this puppy alone on the roa...  dabcf0e55       7.0
# 14910  Sesiapa berminat boleh hubungi saya. Area Batu...  23d3ea5b8       0.0
# 14919  This sweet girl we called Frigga, was found wa...  a9391d398       4.0
# 14923  Same puppy as previous posting. This posting i...  6097a5c1d       0.0
# 14924  Adopters must vaccinate, spay and keep her ind...  5a358b56f       6.0
# 14926  Male-2 mths+. Healthy, playful and active. Ado...  81bc89458       4.0
# 14930  Friendly and loyal mongrel looking for a home....  1f70f8112       3.0
# 14934                           sangat aktif dan manja..  05a839a89       6.0
# 14935  the 2 kittens follow my friend into our house(...  811b66c3e       5.0
# 14936                               Kittens for adoption  edcaed3a4       4.0
# 14954                                 Very small puppies  d3faf6a0e       0.0
# 14959  Hi, I'm King. DOB: Feb Adoption fee applies. F...  a5c5278b8       3.0
# 14968  Can anyone give these cute kittens a loving an...  e50d881a7       2.0
# 14970  One stray dog came to my house and gave birth ...  82ee2f3e9       3.0
# 14972  kofi's clever, cute, and compact.As a testamen...  b3101cf5c       3.0
# 14973                                       For Adoption  941880ea3       5.0
# 14979  SambaBoy makes a good companion dog. Needs lov...  b7fcfa1e6       5.0
# 14984                              abandoned,but healthy  f5dc70d35       1.0
# 14988  I have 4 kittens that need to be adopt urgentl...  dc0935a84       3.0
#
#        AdoptionSpeed agecat  breedcat
# 1                  0      1         0
# 5                  2      3         2
# 7                  3      0         0
# 8                  1      2         0
# 9                  4      4         0
# 13                 1      2         0
# 14                 2      3         0
# 19                 4      1         2
# 26                 1      2         0
# 27                 2      1         2
# 33                 3      3         2
# 34                 4      3         2
# 36                 4      5         0
# 39                 3      4         0
# 52                 3      2         0
# 55                 2      3         0
# 59                 4      2         2
# 63                 2      2         0
# 66                 4      3         2
# 71                 3      1         0
# 74                 2      1         2
# 78                 1      2         0
# 79                 3      1         0
# 80                 4      2         0
# 84                 3      4         0
# 85                 2      1         0
# 87                 2      2         0
# 88                 3      4         0
# 90                 3      1         0
# 92                 4      1         0
# ...              ...    ...       ...
# 14856              1      4         0
# 14860              3      1         0
# 14869              1      1         0
# 14871              4      2         0
# 14875              3      4         0
# 14877              2      3         2
# 14878              3      3         0
# 14880              1      5         2
# 14887              4      1         0
# 14893              4      1         0
# 14895              1      2         0
# 14902              1      2         0
# 14910              4      1         2
# 14919              4      5         0
# 14923              0      2         0
# 14924              3      2         0
# 14926              2      2         2
# 14930              1      4         0
# 14934              4      3         0
# 14935              1      1         2
# 14936              3      2         2
# 14954              4      0         0
# 14959              2      5         2
# 14968              4      2         2
# 14970              3      2         0
# 14972              1      2         2
# 14973              2      2         0
# 14979              4      4         0
# 14984              4      5         0
# 14988              2      2         2
#
# [4044 rows x 26 columns]

# %%
#Set class as 2
df['namecat'] = [1 for i in range(len(df))]
df.loc[names,'namecat'] = 0
df
# Out:
#        Type                                 Name  Age  Breed1  Breed2  Gender  \
# 0         2                               Nibble    3     299       0       1
# 1         2                          No Name Yet    1     265       0       1
# 2         1                               Brisco    1     307       0       1
# 3         1                                 Miko    4     307       0       2
# 4         1                               Hunter    1     307       0       1
# 5         2                                  NaN    3     266       0       2
# 6         2                                BULAT   12     264     264       1
# 7         1              Siu Pak & Her 6 Puppies    0     307       0       2
# 8         2                                  NaN    2     265       0       2
# 9         2                                Kitty   12     265       0       2
# 10        1                                 Bear    2     307       0       1
# 11        2                                 Kali    3     264       0       2
# 12        1                               Peanut    2     307       0       1
# 13        2              2 Mths Old Cute Kitties    2     265       0       3
# 14        1                             Lost Dog    3     307       0       2
# 15        1                                  Max   78     218     205       1
# 16        2                              Brownie    6     266       0       2
# 17        1                              Blackie    8     307     307       2
# 18        1                               Beauty    2     307       0       2
# 19        2                                  NaN    1     266       0       3
# 20        1                               Godiva   12     307       0       2
# 21        1                               Tigers    3     307       0       2
# 22        2    Kenit, Kenot, Techit, Keyad, Owen    0     114       0       3
# 23        1                                Donut   10     307     117       2
# 24        2                              Cikenet    3     266       0       1
# 25        2                             Garfield   36     285     251       1
# 26        2                              No Name    2     285     265       1
# 27        2                              No Name    1     266       0       2
# 28        1                               Hunter   14     189       0       1
# 29        2                               Pepper    1     266       0       2
# ...     ...                                  ...  ...     ...     ...     ...
# 14963     2                              Boceyyy    6     276       0       1
# 14964     2                                Panbe   36     265       0       1
# 14965     2                                Manis    2     266       0       2
# 14966     2                               Belang    1     265       0       1
# 14967     2                              Doremon   24     265       0       2
# 14968     2                      Sentul Kittiens    2     266       0       3
# 14969     2                               Tommie   10     266       0       1
# 14970     1              KL Puppies For Adoption    2     307       0       2
# 14971     2                                Omari    5     265       0       1
# 14972     2                         Kofi (annan)    2     266       0       1
# 14973     1                                 Zee4    2     307     307       2
# 14974     1                              Ang Ang    2     307       0       1
# 14975     1                               Wormmy   24     307       0       2
# 14976     2                        Cici N Shelly   84     264     264       3
# 14977     2                               Kimchi    3     254       0       2
# 14978     1                                Ethio    4     307       0       2
# 14979     1                             SambaBoy    6     307       0       1
# 14980     1                                Bella   24     307     307       2
# 14981     1                                Patch    8     307       0       2
# 14982     2                 âªMami's Babies âª    2     266       0       2
# 14983     1                                Alger    3     307       0       1
# 14984     1                                  NaN   60     307       0       2
# 14985     1                                Terry   24     179     307       1
# 14986     2  Pets + Strays : BlueEyed BlackWhite    1     266       0       2
# 14987     1                                Snowy    6     195       0       2
# 14988     2                                  NaN    2     266       0       3
# 14989     2                       Serato & Eddie   60     265     264       3
# 14990     2                              Monkies    2     265     266       3
# 14991     2                              Ms Daym    9     266       0       2
# 14992     1                                 Fili    1     307     307       1
#
#        Color1  Color2  Color3  MaturitySize  ...  State  \
# 0           1       7       0             1  ...  41326
# 1           1       2       0             2  ...  41401
# 2           2       7       0             2  ...  41326
# 3           1       2       0             2  ...  41401
# 14988  I have 4 kittens that need to be adopt urgentl...  dc0935a84       3.0
# 14989  Serato(female cat- 3 color) is 4 years old and...  a01ab5b30       3.0
# 14990  Mix breed, good temperament kittens. Love huma...  d981b6395       5.0
# 14991  she is very shy..adventures and independent..s...  e4da1c9e4       3.0
# 14992  Fili just loves laying around and also loves b...  a83d95ead       1.0
#
#        AdoptionSpeed  agecat breedcat  namecat
# 0                  2       3        0        1
# 1                  0       1        0        0
# 2                  3       1        0        1
# 3                  2       3        0        1
# 4                  2       1        0        1
# 5                  2       3        2        0
# 6                  1       4        0        1
# 7                  3       0        0        0
# 8                  1       2        0        0
# 9                  4       4        0        0
# 10                 1       2        0        1
# 11                 1       3        0        1
# 12                 2       2        0        1
# 13                 1       2        0        0
# 14                 2       3        0        0
# 15                 4       5        2        1
# 16                 3       4        2        1
# 17                 4       4        0        1
# 18                 2       2        0        1
# 19                 4       1        2        0
# 20                 2       4        0        1
# 21                 4       3        0        1
# 22                 4       0        2        1
# 23                 4       4        0        1
# 24                 1       3        2        1
# 25                 2       5        2        1
# 26                 1       2        0        0
# 27                 2       1        2        0
# 28                 3       5        2        1
# 29                 2       1        2        1
# ...              ...     ...      ...      ...
# 14963              1       4        2        1
# 14964              4       5        0        1
# 14965              1       2        2        1
# 14966              2       1        0        1
# 14967              1       5        0        1
# 14968              4       2        2        0
# 14969              4       4        2        1
# 14970              3       2        0        0
# 14971              3       4        0        1
# 14972              1       2        2        0
# 14973              2       2        0        0
# 14974              2       2        0        1
# 14975              4       5        0        1
# 14976              3       5        0        1
# 14977              4       3        2        1
# 14978              4       3        0        1
# 14979              4       4        0        0
# 14980              4       5        0        1
# 14981              3       4        0        1
# 14982              3       2        2        1
# 14983              2       3        0        1
# 14984              4       5        0        0
# 14985              4       5        0        1
# 14986              3       1        2        1
# 14987              0       4        2        1
# 14988              2       2        2        0
# 14989              4       5        0        1
# 14990              3       2        0        1
# 14991              4       4        2        1
# 14992              3       1        0        1
#
# [14993 rows x 27 columns]

# %%
make_bar_chart(df['namecat'])

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='namecat', main_count=main_count, title='by pet name')

# %%
make_bar_stack(data=df, hue="namecat")

# %% [markdown]
# We don't see a big diference between this class's, let's see diff of name vs no_name

# %%
#list of proibided strings
prb = ['NO NAME']
names = []
for i, name in enumerate(df['Name']):
        if is_number(name) is True or name.isdigit() is True:
            continue
        name = name.upper()
        if any(string in name for string in prb):
            names.append(i)

# %%
#Set
df['namecat'] = [1 for i in range(len(df))]
df.loc[names,'namecat'] = 0
df
# Out:
#        Type                                 Name  Age  Breed1  Breed2  Gender  \
# 0         2                               Nibble    3     299       0       1
# 1         2                          No Name Yet    1     265       0       1
# 2         1                               Brisco    1     307       0       1
# 3         1                                 Miko    4     307       0       2
# 4         1                               Hunter    1     307       0       1
# 5         2                                  NaN    3     266       0       2
# 6         2                                BULAT   12     264     264       1
# 7         1              Siu Pak & Her 6 Puppies    0     307       0       2
# 8         2                                  NaN    2     265       0       2
# 9         2                                Kitty   12     265       0       2
# 10        1                                 Bear    2     307       0       1
# 11        2                                 Kali    3     264       0       2
# 12        1                               Peanut    2     307       0       1
# 13        2              2 Mths Old Cute Kitties    2     265       0       3
# 14        1                             Lost Dog    3     307       0       2
# 15        1                                  Max   78     218     205       1
# 16        2                              Brownie    6     266       0       2
# 17        1                              Blackie    8     307     307       2
# 18        1                               Beauty    2     307       0       2
# 19        2                                  NaN    1     266       0       3
# 20        1                               Godiva   12     307       0       2
# 21        1                               Tigers    3     307       0       2
# 22        2    Kenit, Kenot, Techit, Keyad, Owen    0     114       0       3
# 23        1                                Donut   10     307     117       2
# 24        2                              Cikenet    3     266       0       1
# 25        2                             Garfield   36     285     251       1
# 26        2                              No Name    2     285     265       1
# 27        2                              No Name    1     266       0       2
# 28        1                               Hunter   14     189       0       1
# 29        2                               Pepper    1     266       0       2
# ...     ...                                  ...  ...     ...     ...     ...
# 14963     2                              Boceyyy    6     276       0       1
# 14964     2                                Panbe   36     265       0       1
# 14965     2                                Manis    2     266       0       2
# 14966     2                               Belang    1     265       0       1
# 14967     2                              Doremon   24     265       0       2
# 14968     2                      Sentul Kittiens    2     266       0       3
# 14969     2                               Tommie   10     266       0       1
# 14970     1              KL Puppies For Adoption    2     307       0       2
# 14971     2                                Omari    5     265       0       1
# 14972     2                         Kofi (annan)    2     266       0       1
# 14973     1                                 Zee4    2     307     307       2
# 14974     1                              Ang Ang    2     307       0       1
# 14975     1                               Wormmy   24     307       0       2
# 14976     2                        Cici N Shelly   84     264     264       3
# 14977     2                               Kimchi    3     254       0       2
# 14978     1                                Ethio    4     307       0       2
# 14979     1                             SambaBoy    6     307       0       1
# 14980     1                                Bella   24     307     307       2
# 14981     1                                Patch    8     307       0       2
# 14982     2                 âªMami's Babies âª    2     266       0       2
# 14983     1                                Alger    3     307       0       1
# 14984     1                                  NaN   60     307       0       2
# 14985     1                                Terry   24     179     307       1
# 14986     2  Pets + Strays : BlueEyed BlackWhite    1     266       0       2
# 14987     1                                Snowy    6     195       0       2
# 14988     2                                  NaN    2     266       0       3
# 14989     2                       Serato & Eddie   60     265     264       3
# 14990     2                              Monkies    2     265     266       3
# 14991     2                              Ms Daym    9     266       0       2
# 14992     1                                 Fili    1     307     307       1
#
#        Color1  Color2  Color3  MaturitySize  ...  State  \
# 0           1       7       0             1  ...  41326
# 1           1       2       0             2  ...  41401
# 2           2       7       0             2  ...  41326
# 3           1       2       0             2  ...  41401
# 4           1       0       0             2  ...  41326
# 5           5       6       0             2  ...  41326
# 6           1       0       0             2  ...  41326
# 7           1       2       7             2  ...  41326
# 8           6       0       0             2  ...  41326
# 9           1       7       0             2  ...  41326
# 10          1       2       7             2  ...  41401
# 11          1       2       5             3  ...  41326
# 12          2       5       6             2  ...  41326
# 13          1       6       7             1  ...  41326
# 14          2       5       7             2  ...  41401
# 15          1       7       0             2  ...  41326
# 16          2       0       0             1  ...  41326
# 17          2       0       0             2  ...  41330
# 18          1       0       0             2  ...  41401
# 19          1       2       7             1  ...  41326
# 7                  3       0        0        1
# 8                  1       2        0        1
# 9                  4       4        0        1
# 10                 1       2        0        1
# 11                 1       3        0        1
# 12                 2       2        0        1
# 13                 1       2        0        1
# 14                 2       3        0        1
# 15                 4       5        2        1
# 16                 3       4        2        1
# 17                 4       4        0        1
# 18                 2       2        0        1
# 19                 4       1        2        1
# 20                 2       4        0        1
# 21                 4       3        0        1
# 22                 4       0        2        1
# 23                 4       4        0        1
# 24                 1       3        2        1
# 25                 2       5        2        1
# 26                 1       2        0        0
# 27                 2       1        2        0
# 28                 3       5        2        1
# 29                 2       1        2        1
# ...              ...     ...      ...      ...
# 14963              1       4        2        1
# 14964              4       5        0        1
# 14965              1       2        2        1
# 14966              2       1        0        1
# 14967              1       5        0        1
# 14968              4       2        2        1
# 14969              4       4        2        1
# 14970              3       2        0        1
# 14971              3       4        0        1
# 14972              1       2        2        1
# 14973              2       2        0        1
# 14974              2       2        0        1
# 14975              4       5        0        1
# 14976              3       5        0        1
# 14977              4       3        2        1
# 14978              4       3        0        1
# 14979              4       4        0        1
# 14980              4       5        0        1
# 14981              3       4        0        1
# 14982              3       2        2        1
# 14983              2       3        0        1
# 14984              4       5        0        1
# 14985              4       5        0        1
# 14986              3       1        2        1
# 14987              0       4        2        1
# 14988              2       2        2        1
# 14989              4       5        0        1
# 14990              3       2        0        1
# 14991              4       4        2        1
# 14992              3       1        0        1
#
# [14993 rows x 27 columns]

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='namecat', main_count=main_count, title='by pet name')

# %% [markdown]
# This way it's seems that no_name as more probability of being choose? Probably because no name means young age

# %%
df['namecat'] = [2 for i in range(len(df))]
prb = ['KITT', 'PUPPY', 'DOG', 'MALE', 'FEMALE','FOR', 'NO NAME', 'NAN', 'BOY', 'GIRL']
names = []
for i, name in enumerate(df['Name']):
        if is_number(name) is True or name.isdigit() is True:
            names.append(i)
        else:
            name = name.upper()
            if len(name) <3 or any(string in name for string in prb)  or any(char.isdigit() for char in name):
                names.append(i)
df.loc[names,'namecat'] = 0

# %%
temp = df['Name'].value_counts()[:100]
names2 = []
for i, name in enumerate(df['Name']):
    if name in temp:
        names2.append(i)
df.loc[names2, 'namecat'] = 1

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='namecat', main_count=main_count, title='by pet name')

# %%
make_bar_stack(data=df, hue="namecat")

# %% [markdown]
# a-z cat ranges

# %%
df['namecat'] = 0
def ab_range(a, b):
    letters = [chr(i) for i in range(ord(a),ord(b)+1)]
    res = []
    for i, name in enumerate(df['Name']):
        if is_number(name) is True or name.isdigit():
            continue
        elif df.loc[i, 'Name'][0].lower() in letters:
            res.append(i)
    #[idx for idx in range(len(df['Name'])) if df.loc[idx, 'Name'][0].lower() in letters and df.loc[idx, 'namecat'] == 2]
    return(res)

# %%
df.loc[ab_range('a','h'), 'namecat'] = 1
df.loc[ab_range('i','r'), 'namecat'] = 2
df.loc[ab_range('s','z'), 'namecat'] = 3

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='namecat', main_count=main_count, title='by pet name')

# %%
make_bar_stack(data=df, hue="namecat")

# %%
df['Adoption'] = 0
df['Adoption'][df.AdoptionSpeed != 4] = 1
# Out:
# C:\Users\Miguel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def gender_features2(name):
    features = {}
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        #features["has({})".format(letter)] = (letter in name.lower())
        features["count({})".format(letter)] = name.lower().count(letter)
    return features

# %%
labeled_names = []
for i in range(len(df)):
    labeled_names.append((df.loc[i ,'Name'], df.loc[i,'Adoption']))

# %%
featuresets = [(gender_features2(str(n)), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
from nltk import NaiveBayesClassifier as NBC
import nltk
classifier = NBC.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.7

# %%
#Roc curve
#import pyroc
pred = []
for feat in df['Name']:
    pred.append(classifier.classify(gender_features2(str(feat))))
#temp = pd.DataFrame(pred)
#temp
#roc_data = pyroc.ROC(df['Adoption'], temp)

#fig, ax = roc_data.plot()
#plt.show()

# %%
#check if both classes are being predicted
for i in pred:
    if i == 0:
        print('yay')
        break
# Out:
# yay

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#                 count(j) = 4                   0 : 1      =      4.3 : 1.0
#                 count(w) = 4                   0 : 1      =      3.6 : 1.0
#                 count(r) = 5                   1 : 0      =      3.5 : 1.0
#                 count(i) = 5                   0 : 1      =      3.3 : 1.0
#                 count(d) = 4                   0 : 1      =      2.6 : 1.0

# %% [markdown]
# Usar resultados do classificador diretamente? riscos overfitting, alternativa generalizar regras para feature engeniring

# %% [markdown]
# - count(j) = 4
#   * 0 : 1      =      4.3 : 1.0
# - count(k) = 3
#   * 1 : 0      =      4.0 : 1.0
# - count(i) = 5
#   * 0 : 1      =      3.3 : 1.0
# - count(r) = 5
#   * 1 : 0      =      2.7 : 1.0
# - count(v) = 3
#   * 0 : 1      =      2.6 : 1.0
# - count(h) = 3
#   * 1 : 0      =      1.9 : 1.0

# %%
#scoring 
names = []
for i, name in enumerate(df['Name']):
    score = 0
    temp = gender_features2(str(name))
    score -= 1.075 * temp['count(j)']
    score += 1.33 * temp['count(k)']
    score -= 0.66 * temp['count(i)']
    score += 0.54 * temp['count(r)']
    score -= 0.86 * temp['count(v)']
    score += 0.66 * temp['count(v)']
    if score > 0:
        names.append(i)
df['namecat'] = 0
df.loc[names, 'namecat'] = 1

# %%
plt.figure(figsize=(18, 8));
make_count_plot(df=df, x='namecat', main_count=main_count, title='by pet name')

# %%
make_bar_stack(data=df, hue="namecat")

# %% [markdown]
# # Color Analyses
#
# Nesta secção irão ser analisadas possibilidades  da combinação dos dados das cores

# %% [markdown]
# Em primeiro lugar irá ser estudada as diferentes categorias de cores.
#
# Vai ser analisada a quantidade de animais com uma cor e com mais de uma cor.

# %% [markdown]
# --> **0 - Apenas uma cor**
#
# --> **1 - Mais que uma cor**

# %%
df['colorcat'] = 0
df.loc[df.Color2 != 0, 'colorcat'] = 1
make_pie(df['colorcat'])
#df.groupby(['colorcat']).agg(['count'])
# Out:
#            Type  Name    Age Breed1 Breed2 Gender Color1 Color2 Color3  \
#           count count  count  count  count  count  count  count  count
# colorcat
# 0          4471  4150   4471   4471   4471   4471   4471   4471   4471
# 1         10522  9586  10522  10522  10522  10522  10522  10522  10522
#
#          MaturitySize  ... Description  PetID PhotoAmt AdoptionSpeed agecat  \
#                 count  ...       count  count    count         count  count
# colorcat               ...
# 0                4471  ...        4468   4471     4471          4471   4471
# 1               10522  ...       10513  10522    10522         10522  10522
#
#          breedcat namecat Adoption bicolor feecat
#             count   count    count   count  count
# colorcat
# 0            4471    4471     4471    4471   4471
# 1           10522   10522    10522   10522  10522
#
# [2 rows x 30 columns]

# %% [markdown]
# A maioria dos Animais tem mais do que uma cor.

# %%
make_bar_stack(data=df, hue="colorcat")

# %% [markdown]
# Não existe grande diferenciação em relação à velocidade de adoção

# %%
#Cores de cães só com uma cor
make_bar_stack(data=df.loc[df['colorcat'] == 0], hue="Color1")

# %% [markdown]
# Podemos ver que as cores 1, 2 e 4 são adoptadas mais lentamente do que as restantes para animais com apenas uma cor.
# # Significativo? (acho que não)

# %% [markdown]
# Nova divisão em 3 categorias:
#
#     0 - unicolor;
#     1 - bicolor;
#     2 - tricolor;

# %%
df['colorcat'] = 0
df.loc[df.Color2 != 0, 'colorcat'] = 1
df.loc[df.Color3 != 0, 'colorcat'] = 2
make_pie(df['colorcat'])
#df.groupby(['colorcat']).agg(['count'])

# %% [markdown]
# Distribuição equilibrada das 3 categorias

# %%
make_bar_stack(data=df, hue="colorcat")

# %% [markdown]
# Não existe grande diferença na velocidade de adoção nestas categorias

# %%
df['bicolor'] = 0
df.loc[df.colorcat == 1 , 'bicolor'] = df['Color1']*10+ df['Color2'] 
make_pie(df.bicolor.loc[df['colorcat'] == 1])

#make_bar_stack(data=df.loc[df['colorcat'] == 1], hue ="bicolor")

# %%
df['bicolor2'] = 0
df.loc[df.bicolor != 0, 'bicolor2'] = 5 # outras bicolors
df.loc[df.bicolor == 12, 'bicolor2'] = 1 # 1-2
df.loc[df.bicolor == 17, 'bicolor2'] = 2 # 1-7
df.loc[df.bicolor == 27, 'bicolor2'] = 3 # 2-7
df.loc[df.bicolor == 67, 'bicolor2'] = 4 # 6-7 - ???

#make_bar_chart(df['bicolor2'])
make_pie(df.bicolor2.loc[df['colorcat'] == 1])

# %%
make_bar_stack(data=df, hue="bicolor2")

# %% [markdown]
# # bicolor2 - 4 ?????????????????????
#
# .
#
# .
#
# .

# %% [markdown]
# # MaturitySize
# MaturitySize - Size at maturity (1 = Small, 2 = Medium, 3 = Large, 4 = Extra Large, 0 = Not Specified)

# %%
make_pie(df.MaturitySize)

# %% [markdown]
# MaturitySize - Size at maturity (1 = Small, 2 = Medium, 3 = Large)
#
# A categoria "4 = Extra Large" apenas contém 0,2% da população.
#
# Para uma melhor análise será adiciona a categoria "4 = Extra Large" à categoria "3 = Large".

# %%
df.loc[df.MaturitySize == 4, 'MaturitySize'] = 3 
make_bar_stack(data=df, hue="MaturitySize")

# %% [markdown]
# # FurLength
#
# FurLength - Fur length (1 = Short, 2 = Medium, 3 = Long, 0 = Not Specified)

# %%
#FurLength 
make_bar_stack(data=df, hue="FurLength")

# %%
#Sterilized
make_bar_stack(data=df, x="Sterilized", hue = "agecat")

make_bar_stack(data=df, x="Sterilized", hue = "Vaccinated")

# %%
#Health
make_bar_stack(data=df, hue="Health")

make_bar_stack(data=df, hue="Health", x="Vaccinated")

make_bar_stack(data=df, hue="Health", x="Sterilized")

# %%
make_bar_stack(data=df.loc[(df["Health"]==1)], hue="Sterilized") #Sem grande impacto

# %%
#Quantity 
make_bar_stack(data=df.loc[(df["Quantity"]<10)], hue="Quantity")

# %%
# Fee
df['feecat'] = 0
df.loc[df.Fee != 0, 'feecat'] = 1
#df.loc[df.Fee > 10, 'feecat'] = 2
#df.loc[df.Fee >= 100 , 'feecat'] = 3
#df.loc[df.Fee >= 500, 'feecat'] = 4
make_bar_stack(data=df, hue="feecat")

# %%
make_bar_stack(data=df.loc[df['feecat']==0], hue="Type")

# %%
make_bar_stack(data=df.loc[df['feecat']==1], hue="Type")

# %% [markdown]
# # Description

# %% [markdown]
# ## Task 1 (Supervised Learning) - Predicting Adoption and Adoption Speed
#
# In this task you should target 3 classification tasks:
# 1. **Predicting  Adoption (binary classification task)**: create a new target from AdoptionSpeed that is 1 if AdoptionSpeed <> 4 and 0 otherwise.
# 2. **Predicting AdoptionSpeed (multiclass classification)**: in this task you should you the original target AdoptionSpeed, whose values are in the set {0, 1, 2, 3 , 4} (5 classes). This is a very difficult problem. You might also want to consider 3 classes (for instance {0-1, 2-3, 4}, or other sets that make sense).
# 3. **Train specialized models for cats and dogs**: train with cat/dog instances and check whether the classification performance changes when Predicting Adoption and Predicting AdoptionSpeed.

# %% [markdown]
# **You should:**
#
# * Choose **one classifier in each category**: Tree models, Rule models, Linear models, Distance-based models, and Probabilistic models.
# * Use cross-validation to evaluate the results.
# * Present and discuss the results for different evaluation measures, present confusion matrices. Remember that not only overall results are important. Check what happens when learning to predict each class.
# * Describe the parameters used for each classifier and how their choice impacted or not the results.
# * Choose the best classifier and fundament you choice.
# * **Discuss critically your choices and the results!**

# %% [markdown]
# ## 1.1. Preprocessing Data for Classification

# %% [markdown]
# ## 1.2. Learning Classifiers

# %% [markdown]
# ...

# %% [markdown]
# ## 1.3. Classification - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## Task 2 (Unsupervised Learning) - Charactering Adopted Pets and Adoption Speed

# %% [markdown]
# In this task you should **use unsupervised learning algorithms and try to characterize pets that were actually adopted and their adoption speed**. You can use:
# * **Association rule mining** to find **associations between the features and the target Adoption/AdoptionSpeed**.
# * **Clustering algorithms to find similar groups of pets**. Is it possible to find groups of pets with the same/similar adoption speed.
# * **Be creative and define your own unsupervised analysis!** What would it be interesting to find out ?

# %% [markdown]
# ## 2.1. Preprocessing Data for Association Rule Mining

# %% [markdown]
# ...

# %% [markdown]
# ## 2.2. Finding Associations

# %% [markdown]
# ...

# %% [markdown]
# ## 2.3 Association Rules - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## 2.4. Preprocessing Data for Clustering

# %% [markdown]
# ...

# %% [markdown]
# ## 2.5. Finding Groups

# %% [markdown]
# ...

# %% [markdown]
# ## 2.6. Clustering - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## 3. Final Comments and Conclusions

# %% [markdown]
# ...
